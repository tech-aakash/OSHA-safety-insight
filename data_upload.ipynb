# %%
import os
import re
import streamlit as st
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient, generate_blob_sas
from datetime import datetime, timedelta
from dotenv import load_dotenv
from azure.ai.formrecognizer import DocumentAnalysisClient
from azure.core.credentials import AzureKeyCredential
from azure.search.documents import SearchClient
from openai import AzureOpenAI
from azure.storage.blob import BlobSasPermissions
from azure.storage.blob import ContentSettings

# %% [markdown]
# Change the container env variables as per the course data

# %%
# Load environment variables from .env file
load_dotenv()

# Set up Azure Blob Storage credentials
AZURE_CONNECTION_STRING = os.getenv("AZURE_CONNECTION_STRING")
AZURE_ACCOUNT_NAME = os.getenv("AZURE_ACCOUNT_NAME")
AZURE_ACCOUNT_KEY = os.getenv("AZURE_ACCOUNT_KEY")
CONTAINER_NAME = os.getenv("CONTAINER_NAME")

# Set up Azure Document Intelligence credentials
FORM_RECOGNIZER_ENDPOINT = os.getenv("AZURE_FORM_RECOGNIZER_ENDPOINT")
FORM_RECOGNIZER_KEY = os.getenv("AZURE_FORM_RECOGNIZER_KEY")

# Set up Azure OpenAI credentials
AZURE_OPENAI_ENDPOINT = os.getenv("AZURE_OPENAI_ENDPOINT")
AZURE_OPENAI_KEY = os.getenv("AZURE_OPENAI_API_KEY")
AZURE_OPENAI_DEPLOYMENT_NAME = os.getenv("AZURE_OPENAI_EMB_DEPLOYMENT_NAME")

# Set up Azure AI Search credentials
SEARCH_ENDPOINT = os.getenv("AZURE_SEARCH_ENDPOINT")
SEARCH_INDEX_NAME = os.getenv("AZURE_SEARCH_INDEX_NAME")
SEARCH_API_KEY = os.getenv("AZURE_SEARCH_API_KEY")

# %%
# Initialize clients
blob_service_client = BlobServiceClient.from_connection_string(AZURE_CONNECTION_STRING)
document_analysis_client = DocumentAnalysisClient(FORM_RECOGNIZER_ENDPOINT, AzureKeyCredential(FORM_RECOGNIZER_KEY))
openai_client = AzureOpenAI(
    api_key=AZURE_OPENAI_KEY,
    api_version="2023-05-15",  # Use the latest supported version
    azure_endpoint=AZURE_OPENAI_ENDPOINT
)
search_client = SearchClient(endpoint=SEARCH_ENDPOINT, index_name=SEARCH_INDEX_NAME, credential=AzureKeyCredential(SEARCH_API_KEY))

# %%
# Function to sanitize document keys
def sanitize_key(key):
    # Replace spaces and invalid characters with underscores
    return re.sub(r"[^a-zA-Z0-9_=-]", "_", key)

# %%
from azure.storage.blob import generate_blob_sas, BlobSasPermissions
import os
from datetime import datetime, timedelta
from azure.storage.blob import BlobServiceClient

def upload_to_blob_storage(file_path):
    """
    Uploads a file to Azure Blob Storage and generates a SAS URL valid for 365 days.
    
    Parameters:
    - file_path (str): Local file path

    Returns:
    - tuple: (SAS URL, document_name) if successful, else (None, None)
    """
    try:
        # Extract file name from the path
        document_name = os.path.basename(file_path)

        # Initialize Blob Service Client
        container_client = blob_service_client.get_container_client(CONTAINER_NAME)
        if not container_client.exists():
            container_client.create_container()

        blob_client = container_client.get_blob_client(document_name)

        # Upload the file
        with open(file_path, "rb") as file_data:
            blob_client.upload_blob(file_data, overwrite=True,content_settings=ContentSettings(content_type='application/pdf'))

        print(f"✅ File '{document_name}' uploaded successfully.")

        # Generate SAS token with 365-day expiry
        expiry_time = datetime.utcnow() + timedelta(days=365)

        sas_token = generate_blob_sas(
            account_name=AZURE_ACCOUNT_NAME,
            container_name=CONTAINER_NAME,
            blob_name=document_name,
            account_key=AZURE_ACCOUNT_KEY,
            permission=BlobSasPermissions(read=True, list=True),
            expiry=expiry_time  # ✅ Set expiry to 365 days
        )

        # Construct the SAS URL
        sas_url = f"https://{AZURE_ACCOUNT_NAME}.blob.core.windows.net/{CONTAINER_NAME}/{document_name}?{sas_token}"
        print(f"✅ SAS URL generated successfully! Expires on: {expiry_time}")
        print(f"✅ SAS URL: {sas_url}")

        return sas_url, document_name  # ✅ Return both SAS URL and document name

    except Exception as e:
        print(f"❌ Error uploading file: {e}")
        return None, None

# %%
def analyze_layout(document_url):
    """
    Extract text from a document using Azure Form Recognizer.
    """
    try:
        print(f"🔹 Debug: Trying to analyze document from URL: {document_url}")  # ✅ Print SAS URL for debugging
        poller = document_analysis_client.begin_analyze_document_from_url("prebuilt-layout", document_url)
        return poller.result()
    except Exception as e:
        print(f"❌ Error analyzing document layout: {e}")
        return None

# %%
# Function to generate embeddings using Azure OpenAI
def generate_embedding(text):
    """
    Generate text embeddings using Azure OpenAI.

    Parameters:
    - text (str): Text to embed

    Returns:
    - List[float]: Embedding vector
    """
    try:
        response = openai_client.embeddings.create(
            input=text,
            model=AZURE_OPENAI_DEPLOYMENT_NAME
        )
        return response.data[0].embedding
    except Exception as e:
        print(f"❌ Error generating embedding: {e}")
        return None

# %%
def process_and_store_document(document_url, document_name):
    """
    Process a document, extract text, generate embeddings, and store in Azure AI Search 
    along with the SAS URL.

    Parameters:
    - document_url (str): The SAS URL of the document.
    - document_name (str): Name of the document.

    Returns:
    - str: Success or error message.
    """
    try:
        # Step 1: Analyze the document layout (extract text)
        result = analyze_layout(document_url)
        if not result:
            return "❌ Failed to analyze document."

        # Step 2: Iterate through pages and process each
        for page in result.pages:
            page_text = " ".join([line.content for line in page.lines])  # Extract text
            embedding = generate_embedding(page_text)  # Generate embedding

            # Sanitize the document key
            document_key = sanitize_key(f"{document_name}_{page.page_number}")

            # Step 3: Construct the document for Azure AI Search
            document = {
                "id": document_key,
                "document_name": document_name,  # ✅ File name is now correctly set
                "page_number": page.page_number,
                "content": page_text,  # ✅ Storing extracted text
                "embedding": embedding,  # ✅ Storing embedding
                "sas_url": document_url  # ✅ Storing SAS URL
            }

            # Step 4: Upload the document to Azure AI Search
            search_client.upload_documents(documents=[document])
            print(f"🔹 Debug: Checking Azure Search Index Status")
            print(search_client.get_document_count())

        return f"✅ Document '{document_name}' processed and stored successfully!"
    

    except Exception as e:
        return f"❌ Error processing and storing document: {e}"

# %%
import os

# Define the folder containing PDFs
folder_path = "/Users/aakashwalavalkar/Desktop/OSHA-safety-insight/OSHA"  # Change this to the actual folder path

# Iterate through each PDF in the folder
for filename in os.listdir(folder_path):
    if filename.lower().endswith(".pdf"):  # Process only PDF files
        file_path = os.path.join(folder_path, filename)

        # Upload and get SAS URL
        sas_url, document_name = upload_to_blob_storage(file_path)

        if sas_url:
            result = process_and_store_document(sas_url, document_name)
            print(f"Processed {filename}: {result}")
        else:
            print(f"Failed to upload {filename}")
# Out:
# ✅ File '29 CFR 1926.155 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:23:54.569745
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.155 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A23%3A54Z&sp=r&sv=2025-05-05&sr=b&sig=Kk1kbUfDpANkJMC60B8b6D2o4Jthg0N2TJE0dEnzH2M%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.155 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A23%3A54Z&sp=r&sv=2025-05-05&sr=b&sig=Kk1kbUfDpANkJMC60B8b6D2o4Jthg0N2TJE0dEnzH2M%3D
# 🔹 Debug: Checking Azure Search Index Status
# 0
# 🔹 Debug: Checking Azure Search Index Status
# 0
# Processed 29 CFR 1926.155 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.155 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.59 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:24:02.196190
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.59 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A24%3A02Z&sp=r&sv=2025-05-05&sr=b&sig=uX4KeXFWP5s92TgiOg/XNtSBo6ba4HkFrq3UGhqu1u4%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.59 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A24%3A02Z&sp=r&sv=2025-05-05&sr=b&sig=uX4KeXFWP5s92TgiOg/XNtSBo6ba4HkFrq3UGhqu1u4%3D
# 🔹 Debug: Checking Azure Search Index Status
# 2
# Processed 29 CFR 1926.59 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.59 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.28 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:24:07.244357
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.28 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A24%3A07Z&sp=r&sv=2025-05-05&sr=b&sig=OOfYOoAYBBrgFWbG8sUlXMkQxi35Pviv2BKFXBpu3HY%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.28 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A24%3A07Z&sp=r&sv=2025-05-05&sr=b&sig=OOfYOoAYBBrgFWbG8sUlXMkQxi35Pviv2BKFXBpu3HY%3D
# 🔹 Debug: Checking Azure Search Index Status
# 3
# Processed 29 CFR 1926.28 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.28 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.151 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:24:13.488745
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.151 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A24%3A13Z&sp=r&sv=2025-05-05&sr=b&sig=/ePwF08jsAKm1HIM4ePa7j7JORQUKljHbT9hghtieCo%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.151 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A24%3A13Z&sp=r&sv=2025-05-05&sr=b&sig=/ePwF08jsAKm1HIM4ePa7j7JORQUKljHbT9hghtieCo%3D
# 🔹 Debug: Checking Azure Search Index Status
# 4
# 🔹 Debug: Checking Azure Search Index Status
# 5
# 🔹 Debug: Checking Azure Search Index Status
# 5
# Processed 29 CFR 1926.151 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.151 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR Part 1926 Subpart C (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:24:21.231504
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR Part 1926 Subpart C (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A24%3A21Z&sp=r&sv=2025-05-05&sr=b&sig=5fi7e/EstGcJE4uSf341rnO8Aep/kZ6xSQ/IaBRwta8%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR Part 1926 Subpart C (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A24%3A21Z&sp=r&sv=2025-05-05&sr=b&sig=5fi7e/EstGcJE4uSf341rnO8Aep/kZ6xSQ/IaBRwta8%3D
# 🔹 Debug: Checking Azure Search Index Status
# 7
# 🔹 Debug: Checking Azure Search Index Status
# 8
# 🔹 Debug: Checking Azure Search Index Status
# 8
# 🔹 Debug: Checking Azure Search Index Status
# 10
# 🔹 Debug: Checking Azure Search Index Status
# 10
# 🔹 Debug: Checking Azure Search Index Status
# 10
# 🔹 Debug: Checking Azure Search Index Status
# 10
# Processed 29 CFR Part 1926 Subpart C (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR Part 1926 Subpart C (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.100 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:24:29.742136
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.100 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A24%3A29Z&sp=r&sv=2025-05-05&sr=b&sig=qWpPYe06k/lxCafzjl4O25A8RbJYViziOqG7pzTg6uc%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.100 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A24%3A29Z&sp=r&sv=2025-05-05&sr=b&sig=qWpPYe06k/lxCafzjl4O25A8RbJYViziOqG7pzTg6uc%3D
# 🔹 Debug: Checking Azure Search Index Status
# 14
# 🔹 Debug: Checking Azure Search Index Status
# 15
# Processed 29 CFR 1926.100 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.100 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.62 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:24:35.158066
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.62 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A24%3A35Z&sp=r&sv=2025-05-05&sr=b&sig=s2qgGhY14Q%2B/YbpixLevMOaQQ9BL86%2BDk8j08otuvzA%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.62 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A24%3A35Z&sp=r&sv=2025-05-05&sr=b&sig=s2qgGhY14Q%2B/YbpixLevMOaQQ9BL86%2BDk8j08otuvzA%3D
# 🔹 Debug: Checking Azure Search Index Status
# 16
# 🔹 Debug: Checking Azure Search Index Status
# 17
# 🔹 Debug: Checking Azure Search Index Status
# 17
# 🔹 Debug: Checking Azure Search Index Status
# 17
# 🔹 Debug: Checking Azure Search Index Status
# 17
# 🔹 Debug: Checking Azure Search Index Status
# 20
# 🔹 Debug: Checking Azure Search Index Status
# 22
# 🔹 Debug: Checking Azure Search Index Status
# 22
# 🔹 Debug: Checking Azure Search Index Status
# 22
# 🔹 Debug: Checking Azure Search Index Status
# 24
# 🔹 Debug: Checking Azure Search Index Status
# 26
# 🔹 Debug: Checking Azure Search Index Status
# 26
# 🔹 Debug: Checking Azure Search Index Status
# 26
# 🔹 Debug: Checking Azure Search Index Status
# 26
# 🔹 Debug: Checking Azure Search Index Status
# 30
# 🔹 Debug: Checking Azure Search Index Status
# 30
# 🔹 Debug: Checking Azure Search Index Status
# 30
# 🔹 Debug: Checking Azure Search Index Status
# 30
# 🔹 Debug: Checking Azure Search Index Status
# 34
# 🔹 Debug: Checking Azure Search Index Status
# 34
# 🔹 Debug: Checking Azure Search Index Status
# 34
# 🔹 Debug: Checking Azure Search Index Status
# 34
# 🔹 Debug: Checking Azure Search Index Status
# 38
# 🔹 Debug: Checking Azure Search Index Status
# 38
# 🔹 Debug: Checking Azure Search Index Status
# 38
# 🔹 Debug: Checking Azure Search Index Status
# 38
# 🔹 Debug: Checking Azure Search Index Status
# 42
# 🔹 Debug: Checking Azure Search Index Status
# 42
# 🔹 Debug: Checking Azure Search Index Status
# 44
# 🔹 Debug: Checking Azure Search Index Status
# 44
# 🔹 Debug: Checking Azure Search Index Status
# 44
# 🔹 Debug: Checking Azure Search Index Status
# 44
# 🔹 Debug: Checking Azure Search Index Status
# 48
# 🔹 Debug: Checking Azure Search Index Status
# 48
# 🔹 Debug: Checking Azure Search Index Status
# 48
# 🔹 Debug: Checking Azure Search Index Status
# 48
# 🔹 Debug: Checking Azure Search Index Status
# 52
# 🔹 Debug: Checking Azure Search Index Status
# 52
# 🔹 Debug: Checking Azure Search Index Status
# 54
# 🔹 Debug: Checking Azure Search Index Status
# 55
# 🔹 Debug: Checking Azure Search Index Status
# 55
# 🔹 Debug: Checking Azure Search Index Status
# 55
# 🔹 Debug: Checking Azure Search Index Status
# 57
# 🔹 Debug: Checking Azure Search Index Status
# 59
# 🔹 Debug: Checking Azure Search Index Status
# 59
# 🔹 Debug: Checking Azure Search Index Status
# 59
# 🔹 Debug: Checking Azure Search Index Status
# 61
# Processed 29 CFR 1926.62 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.62 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.55 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:25:05.236535
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.55 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A25%3A05Z&sp=r&sv=2025-05-05&sr=b&sig=U8WfVhryZKAMAfRSMV6fEGe0a1SDhaM%2B70%2BTWOB%2BiF8%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.55 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A25%3A05Z&sp=r&sv=2025-05-05&sr=b&sig=U8WfVhryZKAMAfRSMV6fEGe0a1SDhaM%2B70%2BTWOB%2BiF8%3D
# 🔹 Debug: Checking Azure Search Index Status
# 63
# 🔹 Debug: Checking Azure Search Index Status
# 63
# 🔹 Debug: Checking Azure Search Index Status
# 63
# 🔹 Debug: Checking Azure Search Index Status
# 63
# 🔹 Debug: Checking Azure Search Index Status
# 67
# 🔹 Debug: Checking Azure Search Index Status
# 67
# 🔹 Debug: Checking Azure Search Index Status
# 67
# 🔹 Debug: Checking Azure Search Index Status
# 70
# 🔹 Debug: Checking Azure Search Index Status
# 70
# 🔹 Debug: Checking Azure Search Index Status
# 70
# 🔹 Debug: Checking Azure Search Index Status
# 70
# 🔹 Debug: Checking Azure Search Index Status
# 74
# 🔹 Debug: Checking Azure Search Index Status
# 74
# 🔹 Debug: Checking Azure Search Index Status
# 74
# 🔹 Debug: Checking Azure Search Index Status
# 74
# 🔹 Debug: Checking Azure Search Index Status
# 78
# 🔹 Debug: Checking Azure Search Index Status
# 78
# 🔹 Debug: Checking Azure Search Index Status
# 78
# 🔹 Debug: Checking Azure Search Index Status
# 78
# 🔹 Debug: Checking Azure Search Index Status
# 82
# 🔹 Debug: Checking Azure Search Index Status
# 82
# Processed 29 CFR 1926.55 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.55 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.20 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:25:21.175140
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.20 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A25%3A21Z&sp=r&sv=2025-05-05&sr=b&sig=m/Qd7ZMmco8wu4bQ3Hy5OOEcCnF7z/ZSjF9O2TAvetA%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.20 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A25%3A21Z&sp=r&sv=2025-05-05&sr=b&sig=m/Qd7ZMmco8wu4bQ3Hy5OOEcCnF7z/ZSjF9O2TAvetA%3D
# 🔹 Debug: Checking Azure Search Index Status
# 84
# 🔹 Debug: Checking Azure Search Index Status
# 84
# Processed 29 CFR 1926.20 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.20 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.66 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:25:27.491614
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.66 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A25%3A27Z&sp=r&sv=2025-05-05&sr=b&sig=OVL8tlir2WJRk55EvhelO8jTxliasVgN99e/98d%2Bli0%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.66 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A25%3A27Z&sp=r&sv=2025-05-05&sr=b&sig=OVL8tlir2WJRk55EvhelO8jTxliasVgN99e/98d%2Bli0%3D
# 🔹 Debug: Checking Azure Search Index Status
# 87
# 🔹 Debug: Checking Azure Search Index Status
# 87
# 🔹 Debug: Checking Azure Search Index Status
# 87
# 🔹 Debug: Checking Azure Search Index Status
# 87
# 🔹 Debug: Checking Azure Search Index Status
# 87
# 🔹 Debug: Checking Azure Search Index Status
# 91
# 🔹 Debug: Checking Azure Search Index Status
# 91
# 🔹 Debug: Checking Azure Search Index Status
# 91
# 🔹 Debug: Checking Azure Search Index Status
# 91
# Processed 29 CFR 1926.66 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.66 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.51 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:25:41.665391
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.51 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A25%3A41Z&sp=r&sv=2025-05-05&sr=b&sig=8C9A2/Yp4ddEQ9/eE2WLAHdJhXKFe/UCrF/oUMQgsGo%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.51 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A25%3A41Z&sp=r&sv=2025-05-05&sr=b&sig=8C9A2/Yp4ddEQ9/eE2WLAHdJhXKFe/UCrF/oUMQgsGo%3D
# 🔹 Debug: Checking Azure Search Index Status
# 95
# 🔹 Debug: Checking Azure Search Index Status
# 95
# 🔹 Debug: Checking Azure Search Index Status
# 95
# Processed 29 CFR 1926.51 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.51 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.104 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:25:48.891815
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.104 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A25%3A48Z&sp=r&sv=2025-05-05&sr=b&sig=1vQaVszqu46ax5GgksVuPkBl/%2BxxKMqHd/knm17bqoU%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.104 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A25%3A48Z&sp=r&sv=2025-05-05&sr=b&sig=1vQaVszqu46ax5GgksVuPkBl/%2BxxKMqHd/knm17bqoU%3D
# 🔹 Debug: Checking Azure Search Index Status
# 98
# 🔹 Debug: Checking Azure Search Index Status
# 98
# Processed 29 CFR 1926.104 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.104 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.56 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:25:55.239776
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.56 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A25%3A55Z&sp=r&sv=2025-05-05&sr=b&sig=Go5wzmzQvfJss21BPYdUD6TsLhpW4p48Bw/CGuJik7E%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.56 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A25%3A55Z&sp=r&sv=2025-05-05&sr=b&sig=Go5wzmzQvfJss21BPYdUD6TsLhpW4p48Bw/CGuJik7E%3D
# 🔹 Debug: Checking Azure Search Index Status
# 100
# 🔹 Debug: Checking Azure Search Index Status
# 100
# Processed 29 CFR 1926.56 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.56 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.65 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:26:01.625981
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.65 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A26%3A01Z&sp=r&sv=2025-05-05&sr=b&sig=FkH1apiDGQyW4JQpigxPMrtJogaP8XqAKA7xKduhEEk%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.65 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A26%3A01Z&sp=r&sv=2025-05-05&sr=b&sig=FkH1apiDGQyW4JQpigxPMrtJogaP8XqAKA7xKduhEEk%3D
# 🔹 Debug: Checking Azure Search Index Status
# 102
# 🔹 Debug: Checking Azure Search Index Status
# 103
# 🔹 Debug: Checking Azure Search Index Status
# 104
# 🔹 Debug: Checking Azure Search Index Status
# 104
# 🔹 Debug: Checking Azure Search Index Status
# 104
# 🔹 Debug: Checking Azure Search Index Status
# 107
# 🔹 Debug: Checking Azure Search Index Status
# 107
# 🔹 Debug: Checking Azure Search Index Status
# 110
# 🔹 Debug: Checking Azure Search Index Status
# 110
# 🔹 Debug: Checking Azure Search Index Status
# 110
# 🔹 Debug: Checking Azure Search Index Status
# 110
# 🔹 Debug: Checking Azure Search Index Status
# 113
# 🔹 Debug: Checking Azure Search Index Status
# 113
# 🔹 Debug: Checking Azure Search Index Status
# 113
# 🔹 Debug: Checking Azure Search Index Status
# 113
# 🔹 Debug: Checking Azure Search Index Status
# 117
# 🔹 Debug: Checking Azure Search Index Status
# 117
# 🔹 Debug: Checking Azure Search Index Status
# 117
# 🔹 Debug: Checking Azure Search Index Status
# 117
# 🔹 Debug: Checking Azure Search Index Status
# 119
# 🔹 Debug: Checking Azure Search Index Status
# 122
# 🔹 Debug: Checking Azure Search Index Status
# 122
# 🔹 Debug: Checking Azure Search Index Status
# 122
# 🔹 Debug: Checking Azure Search Index Status
# 125
# 🔹 Debug: Checking Azure Search Index Status
# 125
# 🔹 Debug: Checking Azure Search Index Status
# 125
# 🔹 Debug: Checking Azure Search Index Status
# 125
# 🔹 Debug: Checking Azure Search Index Status
# 129
# 🔹 Debug: Checking Azure Search Index Status
# 129
# 🔹 Debug: Checking Azure Search Index Status
# 129
# 🔹 Debug: Checking Azure Search Index Status
# 131
# 🔹 Debug: Checking Azure Search Index Status
# 133
# 🔹 Debug: Checking Azure Search Index Status
# 133
# 🔹 Debug: Checking Azure Search Index Status
# 133
# 🔹 Debug: Checking Azure Search Index Status
# 133
# 🔹 Debug: Checking Azure Search Index Status
# 137
# 🔹 Debug: Checking Azure Search Index Status
# 137
# 🔹 Debug: Checking Azure Search Index Status
# 137
# 🔹 Debug: Checking Azure Search Index Status
# 137
# 🔹 Debug: Checking Azure Search Index Status
# 141
# 🔹 Debug: Checking Azure Search Index Status
# 141
# 🔹 Debug: Checking Azure Search Index Status
# 141
# 🔹 Debug: Checking Azure Search Index Status
# 144
# 🔹 Debug: Checking Azure Search Index Status
# 144
# 🔹 Debug: Checking Azure Search Index Status
# 144
# 🔹 Debug: Checking Azure Search Index Status
# 144
# 🔹 Debug: Checking Azure Search Index Status
# 148
# 🔹 Debug: Checking Azure Search Index Status
# 148
# 🔹 Debug: Checking Azure Search Index Status
# 148
# 🔹 Debug: Checking Azure Search Index Status
# 148
# 🔹 Debug: Checking Azure Search Index Status
# 152
# 🔹 Debug: Checking Azure Search Index Status
# 152
# 🔹 Debug: Checking Azure Search Index Status
# 152
# 🔹 Debug: Checking Azure Search Index Status
# 152
# 🔹 Debug: Checking Azure Search Index Status
# 156
# 🔹 Debug: Checking Azure Search Index Status
# 156
# 🔹 Debug: Checking Azure Search Index Status
# 156
# 🔹 Debug: Checking Azure Search Index Status
# 156
# 🔹 Debug: Checking Azure Search Index Status
# 159
# 🔹 Debug: Checking Azure Search Index Status
# 161
# 🔹 Debug: Checking Azure Search Index Status
# 161
# 🔹 Debug: Checking Azure Search Index Status
# 163
# 🔹 Debug: Checking Azure Search Index Status
# 163
# 🔹 Debug: Checking Azure Search Index Status
# 163
# 🔹 Debug: Checking Azure Search Index Status
# 163
# 🔹 Debug: Checking Azure Search Index Status
# 167
# 🔹 Debug: Checking Azure Search Index Status
# 167
# 🔹 Debug: Checking Azure Search Index Status
# 167
# 🔹 Debug: Checking Azure Search Index Status
# 167
# 🔹 Debug: Checking Azure Search Index Status
# 171
# Processed 29 CFR 1926.65 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.65 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.23 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:26:40.562720
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.23 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A26%3A40Z&sp=r&sv=2025-05-05&sr=b&sig=/7Ot6ghGkVOVbJ7kF3U2Ya7Mur4Za8jqOlbZOnyeih8%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.23 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A26%3A40Z&sp=r&sv=2025-05-05&sr=b&sig=/7Ot6ghGkVOVbJ7kF3U2Ya7Mur4Za8jqOlbZOnyeih8%3D
# 🔹 Debug: Checking Azure Search Index Status
# 172
# Processed 29 CFR 1926.23 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.23 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.201 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:26:45.689638
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.201 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A26%3A45Z&sp=r&sv=2025-05-05&sr=b&sig=KDbBLaCvChpRNhvIMfxls5OrfTgWtbWH/bpLaQrpy4A%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.201 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A26%3A45Z&sp=r&sv=2025-05-05&sr=b&sig=KDbBLaCvChpRNhvIMfxls5OrfTgWtbWH/bpLaQrpy4A%3D
# 🔹 Debug: Checking Azure Search Index Status
# 173
# Processed 29 CFR 1926.201 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.201 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.107 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:26:50.292170
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.107 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A26%3A50Z&sp=r&sv=2025-05-05&sr=b&sig=fHjg6UHYLdvQyEFdxYVlRndfi7BSWJaguxuKwabwVQ0%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.107 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A26%3A50Z&sp=r&sv=2025-05-05&sr=b&sig=fHjg6UHYLdvQyEFdxYVlRndfi7BSWJaguxuKwabwVQ0%3D
# 🔹 Debug: Checking Azure Search Index Status
# 174
# Processed 29 CFR 1926.107 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.107 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.250 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:26:54.300387
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.250 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A26%3A54Z&sp=r&sv=2025-05-05&sr=b&sig=h5JEi073KkZV2woOpHZbKoqVU8U8XVDKHFZc8DfJ97A%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.250 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A26%3A54Z&sp=r&sv=2025-05-05&sr=b&sig=h5JEi073KkZV2woOpHZbKoqVU8U8XVDKHFZc8DfJ97A%3D
# 🔹 Debug: Checking Azure Search Index Status
# 175
# 🔹 Debug: Checking Azure Search Index Status
# 176
# Processed 29 CFR 1926.250 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.250 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.34 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:27:00.632171
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.34 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A27%3A00Z&sp=r&sv=2025-05-05&sr=b&sig=txRTp28yW%2BDK9EjeM9QBRgcC/fIHhkxICRJsuDp0bqI%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.34 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A27%3A00Z&sp=r&sv=2025-05-05&sr=b&sig=txRTp28yW%2BDK9EjeM9QBRgcC/fIHhkxICRJsuDp0bqI%3D
# 🔹 Debug: Checking Azure Search Index Status
# 177
# Processed 29 CFR 1926.34 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.34 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.30 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:27:06.050222
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.30 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A27%3A06Z&sp=r&sv=2025-05-05&sr=b&sig=49otDdMn3TOMMQttgV3TMb1S9boahIGpxhEHDHSqXLY%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.30 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A27%3A06Z&sp=r&sv=2025-05-05&sr=b&sig=49otDdMn3TOMMQttgV3TMb1S9boahIGpxhEHDHSqXLY%3D
# 🔹 Debug: Checking Azure Search Index Status
# 178
# Processed 29 CFR 1926.30 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.30 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.95 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:27:09.839924
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.95 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A27%3A09Z&sp=r&sv=2025-05-05&sr=b&sig=Om7UWchPnJeWCTPL9zD8PIeJ8%2B7SJZPsENn21AqmvaM%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.95 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A27%3A09Z&sp=r&sv=2025-05-05&sr=b&sig=Om7UWchPnJeWCTPL9zD8PIeJ8%2B7SJZPsENn21AqmvaM%3D
# 🔹 Debug: Checking Azure Search Index Status
# 179
# 🔹 Debug: Checking Azure Search Index Status
# 179
# Processed 29 CFR 1926.95 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.95 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.152 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:27:15.533982
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.152 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A27%3A15Z&sp=r&sv=2025-05-05&sr=b&sig=WuGGr81IjnBIuDmYlz76e3Wl7RsYVe/TdF1G6qQpxwQ%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.152 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A27%3A15Z&sp=r&sv=2025-05-05&sr=b&sig=WuGGr81IjnBIuDmYlz76e3Wl7RsYVe/TdF1G6qQpxwQ%3D
# 🔹 Debug: Checking Azure Search Index Status
# 181
# 🔹 Debug: Checking Azure Search Index Status
# 181
# 🔹 Debug: Checking Azure Search Index Status
# 181
# 🔹 Debug: Checking Azure Search Index Status
# 181
# 🔹 Debug: Checking Azure Search Index Status
# 185
# 🔹 Debug: Checking Azure Search Index Status
# 185
# 🔹 Debug: Checking Azure Search Index Status
# 185
# 🔹 Debug: Checking Azure Search Index Status
# 185
# 🔹 Debug: Checking Azure Search Index Status
# 189
# 🔹 Debug: Checking Azure Search Index Status
# 190
# 🔹 Debug: Checking Azure Search Index Status
# 190
# 🔹 Debug: Checking Azure Search Index Status
# 190
# 🔹 Debug: Checking Azure Search Index Status
# 193
# 🔹 Debug: Checking Azure Search Index Status
# 193
# 🔹 Debug: Checking Azure Search Index Status
# 193
# 🔹 Debug: Checking Azure Search Index Status
# 193
# 🔹 Debug: Checking Azure Search Index Status
# 198
# 🔹 Debug: Checking Azure Search Index Status
# 198
# 🔹 Debug: Checking Azure Search Index Status
# 198
# 🔹 Debug: Checking Azure Search Index Status
# 200
# 🔹 Debug: Checking Azure Search Index Status
# 200
# 🔹 Debug: Checking Azure Search Index Status
# 200
# 🔹 Debug: Checking Azure Search Index Status
# 200
# 🔹 Debug: Checking Azure Search Index Status
# 204
# 🔹 Debug: Checking Azure Search Index Status
# 204
# Processed 29 CFR 1926.152 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.152 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.50 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:27:34.618463
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.50 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A27%3A34Z&sp=r&sv=2025-05-05&sr=b&sig=FyyzzhsAdHd1garZlEdnEKMEmisXzvuwIHKhNMOHeb4%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.50 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A27%3A34Z&sp=r&sv=2025-05-05&sr=b&sig=FyyzzhsAdHd1garZlEdnEKMEmisXzvuwIHKhNMOHeb4%3D
# 🔹 Debug: Checking Azure Search Index Status
# 206
# 🔹 Debug: Checking Azure Search Index Status
# 206
# 🔹 Debug: Checking Azure Search Index Status
# 208
# Processed 29 CFR 1926.50 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.50 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.105 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:27:41.357290
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.105 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A27%3A41Z&sp=r&sv=2025-05-05&sr=b&sig=52bcayzi2Wfyk16CjswWW3RtxceYiKg4r%2BLEyqrRrww%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.105 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A27%3A41Z&sp=r&sv=2025-05-05&sr=b&sig=52bcayzi2Wfyk16CjswWW3RtxceYiKg4r%2BLEyqrRrww%3D
# 🔹 Debug: Checking Azure Search Index Status
# 209
# Processed 29 CFR 1926.105 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.105 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.101 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:27:47.485983
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.101 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A27%3A47Z&sp=r&sv=2025-05-05&sr=b&sig=twVs%2BGsE8PYvm4r1sAANDKcT9nhRCSocNSDUKqNrr3Q%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.101 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A27%3A47Z&sp=r&sv=2025-05-05&sr=b&sig=twVs%2BGsE8PYvm4r1sAANDKcT9nhRCSocNSDUKqNrr3Q%3D
# 🔹 Debug: Checking Azure Search Index Status
# 210
# Processed 29 CFR 1926.101 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.101 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.54 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:27:51.506698
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.54 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A27%3A51Z&sp=r&sv=2025-05-05&sr=b&sig=EksSJaFFzLxXkJnVLNKUYBd%2BOSSRHdxcoh3/8T8668M%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.54 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A27%3A51Z&sp=r&sv=2025-05-05&sr=b&sig=EksSJaFFzLxXkJnVLNKUYBd%2BOSSRHdxcoh3/8T8668M%3D
# 🔹 Debug: Checking Azure Search Index Status
# 211
# 🔹 Debug: Checking Azure Search Index Status
# 211
# Processed 29 CFR 1926.54 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.54 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.25 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:28:02.680406
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.25 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A28%3A02Z&sp=r&sv=2025-05-05&sr=b&sig=%2BQ1O7Cm3j70wsrA36fq6MOX3lL9zse4Yle5jAGcxzIk%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.25 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A28%3A02Z&sp=r&sv=2025-05-05&sr=b&sig=%2BQ1O7Cm3j70wsrA36fq6MOX3lL9zse4Yle5jAGcxzIk%3D
# 🔹 Debug: Checking Azure Search Index Status
# 213
# Processed 29 CFR 1926.25 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.25 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '1169_USA_29-CFR-1926_OSHA_Eff-04-2017.pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:28:07.141319
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/1169_USA_29-CFR-1926_OSHA_Eff-04-2017.pdf?se=2026-11-05T17%3A28%3A07Z&sp=r&sv=2025-05-05&sr=b&sig=BiQQpWwFRWeS6v2Gn98qTH00c13Y6S3P3AxyS3z5cuo%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/1169_USA_29-CFR-1926_OSHA_Eff-04-2017.pdf?se=2026-11-05T17%3A28%3A07Z&sp=r&sv=2025-05-05&sr=b&sig=BiQQpWwFRWeS6v2Gn98qTH00c13Y6S3P3AxyS3z5cuo%3D
# 🔹 Debug: Checking Azure Search Index Status
# 214
# 🔹 Debug: Checking Azure Search Index Status
# 214
# 🔹 Debug: Checking Azure Search Index Status
# 215
# 🔹 Debug: Checking Azure Search Index Status
# 217
# 🔹 Debug: Checking Azure Search Index Status
# 217
# 🔹 Debug: Checking Azure Search Index Status
# 217
# 🔹 Debug: Checking Azure Search Index Status
# 220
# 🔹 Debug: Checking Azure Search Index Status
# 220
# 🔹 Debug: Checking Azure Search Index Status
# 220
# 🔹 Debug: Checking Azure Search Index Status
# 220
# 🔹 Debug: Checking Azure Search Index Status
# 224
# 🔹 Debug: Checking Azure Search Index Status
# 224
# 🔹 Debug: Checking Azure Search Index Status
# 224
# 🔹 Debug: Checking Azure Search Index Status
# 227
# 🔹 Debug: Checking Azure Search Index Status
# 227
# 🔹 Debug: Checking Azure Search Index Status
# 227
# 🔹 Debug: Checking Azure Search Index Status
# 227
# 🔹 Debug: Checking Azure Search Index Status
# 231
# 🔹 Debug: Checking Azure Search Index Status
# 231
# 🔹 Debug: Checking Azure Search Index Status
# 231
# 🔹 Debug: Checking Azure Search Index Status
# 234
# 🔹 Debug: Checking Azure Search Index Status
# 234
# 🔹 Debug: Checking Azure Search Index Status
# 234
# 🔹 Debug: Checking Azure Search Index Status
# 234
# 🔹 Debug: Checking Azure Search Index Status
# 238
# 🔹 Debug: Checking Azure Search Index Status
# 238
# 🔹 Debug: Checking Azure Search Index Status
# 241
# 🔹 Debug: Checking Azure Search Index Status
# 241
# 🔹 Debug: Checking Azure Search Index Status
# 241
# 🔹 Debug: Checking Azure Search Index Status
# 241
# 🔹 Debug: Checking Azure Search Index Status
# 244
# 🔹 Debug: Checking Azure Search Index Status
# 244
# 🔹 Debug: Checking Azure Search Index Status
# 247
# 🔹 Debug: Checking Azure Search Index Status
# 247
# 🔹 Debug: Checking Azure Search Index Status
# 247
# 🔹 Debug: Checking Azure Search Index Status
# 249
# 🔹 Debug: Checking Azure Search Index Status
# 249
# 🔹 Debug: Checking Azure Search Index Status
# 251
# 🔹 Debug: Checking Azure Search Index Status
# 251
# 🔹 Debug: Checking Azure Search Index Status
# 253
# 🔹 Debug: Checking Azure Search Index Status
# 253
# 🔹 Debug: Checking Azure Search Index Status
# 255
# 🔹 Debug: Checking Azure Search Index Status
# 255
# 🔹 Debug: Checking Azure Search Index Status
# 258
# 🔹 Debug: Checking Azure Search Index Status
# 258
# 🔹 Debug: Checking Azure Search Index Status
# 258
# 🔹 Debug: Checking Azure Search Index Status
# 258
# 🔹 Debug: Checking Azure Search Index Status
# 261
# 🔹 Debug: Checking Azure Search Index Status
# 261
# 🔹 Debug: Checking Azure Search Index Status
# 261
# 🔹 Debug: Checking Azure Search Index Status
# 264
# 🔹 Debug: Checking Azure Search Index Status
# 264
# 🔹 Debug: Checking Azure Search Index Status
# 264
# 🔹 Debug: Checking Azure Search Index Status
# 264
# 🔹 Debug: Checking Azure Search Index Status
# 266
# 🔹 Debug: Checking Azure Search Index Status
# 269
# 🔹 Debug: Checking Azure Search Index Status
# 269
# 🔹 Debug: Checking Azure Search Index Status
# 269
# 🔹 Debug: Checking Azure Search Index Status
# 269
# 🔹 Debug: Checking Azure Search Index Status
# 273
# 🔹 Debug: Checking Azure Search Index Status
# 273
# 🔹 Debug: Checking Azure Search Index Status
# 273
# 🔹 Debug: Checking Azure Search Index Status
# 273
# 🔹 Debug: Checking Azure Search Index Status
# 277
# 🔹 Debug: Checking Azure Search Index Status
# 277
# 🔹 Debug: Checking Azure Search Index Status
# 277
# 🔹 Debug: Checking Azure Search Index Status
# 280
# 🔹 Debug: Checking Azure Search Index Status
# 280
# 🔹 Debug: Checking Azure Search Index Status
# 280
# 🔹 Debug: Checking Azure Search Index Status
# 280
# 🔹 Debug: Checking Azure Search Index Status
# 280
# 🔹 Debug: Checking Azure Search Index Status
# 285
# 🔹 Debug: Checking Azure Search Index Status
# 285
# 🔹 Debug: Checking Azure Search Index Status
# 285
# 🔹 Debug: Checking Azure Search Index Status
# 285
# 🔹 Debug: Checking Azure Search Index Status
# 289
# 🔹 Debug: Checking Azure Search Index Status
# 289
# 🔹 Debug: Checking Azure Search Index Status
# 289
# 🔹 Debug: Checking Azure Search Index Status
# 292
# 🔹 Debug: Checking Azure Search Index Status
# 292
# 🔹 Debug: Checking Azure Search Index Status
# 292
# 🔹 Debug: Checking Azure Search Index Status
# 295
# 🔹 Debug: Checking Azure Search Index Status
# 295
# 🔹 Debug: Checking Azure Search Index Status
# 295
# 🔹 Debug: Checking Azure Search Index Status
# 298
# 🔹 Debug: Checking Azure Search Index Status
# 298
# 🔹 Debug: Checking Azure Search Index Status
# 298
# 🔹 Debug: Checking Azure Search Index Status
# 301
# 🔹 Debug: Checking Azure Search Index Status
# 301
# 🔹 Debug: Checking Azure Search Index Status
# 301
# 🔹 Debug: Checking Azure Search Index Status
# 301
# 🔹 Debug: Checking Azure Search Index Status
# 305
# 🔹 Debug: Checking Azure Search Index Status
# 305
# 🔹 Debug: Checking Azure Search Index Status
# 305
# 🔹 Debug: Checking Azure Search Index Status
# 305
# 🔹 Debug: Checking Azure Search Index Status
# 309
# 🔹 Debug: Checking Azure Search Index Status
# 309
# 🔹 Debug: Checking Azure Search Index Status
# 311
# 🔹 Debug: Checking Azure Search Index Status
# 312
# 🔹 Debug: Checking Azure Search Index Status
# 312
# 🔹 Debug: Checking Azure Search Index Status
# 312
# 🔹 Debug: Checking Azure Search Index Status
# 314
# 🔹 Debug: Checking Azure Search Index Status
# 316
# 🔹 Debug: Checking Azure Search Index Status
# 316
# 🔹 Debug: Checking Azure Search Index Status
# 316
# 🔹 Debug: Checking Azure Search Index Status
# 319
# 🔹 Debug: Checking Azure Search Index Status
# 319
# 🔹 Debug: Checking Azure Search Index Status
# 319
# 🔹 Debug: Checking Azure Search Index Status
# 319
# 🔹 Debug: Checking Azure Search Index Status
# 319
# 🔹 Debug: Checking Azure Search Index Status
# 324
# 🔹 Debug: Checking Azure Search Index Status
# 324
# 🔹 Debug: Checking Azure Search Index Status
# 326
# 🔹 Debug: Checking Azure Search Index Status
# 326
# 🔹 Debug: Checking Azure Search Index Status
# 328
# 🔹 Debug: Checking Azure Search Index Status
# 329
# 🔹 Debug: Checking Azure Search Index Status
# 330
# 🔹 Debug: Checking Azure Search Index Status
# 330
# 🔹 Debug: Checking Azure Search Index Status
# 332
# 🔹 Debug: Checking Azure Search Index Status
# 332
# 🔹 Debug: Checking Azure Search Index Status
# 334
# 🔹 Debug: Checking Azure Search Index Status
# 334
# 🔹 Debug: Checking Azure Search Index Status
# 334
# 🔹 Debug: Checking Azure Search Index Status
# 338
# 🔹 Debug: Checking Azure Search Index Status
# 338
# 🔹 Debug: Checking Azure Search Index Status
# 339
# 🔹 Debug: Checking Azure Search Index Status
# 339
# 🔹 Debug: Checking Azure Search Index Status
# 341
# 🔹 Debug: Checking Azure Search Index Status
# 341
# 🔹 Debug: Checking Azure Search Index Status
# 343
# 🔹 Debug: Checking Azure Search Index Status
# 343
# 🔹 Debug: Checking Azure Search Index Status
# 343
# 🔹 Debug: Checking Azure Search Index Status
# 343
# 🔹 Debug: Checking Azure Search Index Status
# 347
# 🔹 Debug: Checking Azure Search Index Status
# 347
# 🔹 Debug: Checking Azure Search Index Status
# 347
# 🔹 Debug: Checking Azure Search Index Status
# 350
# 🔹 Debug: Checking Azure Search Index Status
# 350
# 🔹 Debug: Checking Azure Search Index Status
# 350
# 🔹 Debug: Checking Azure Search Index Status
# 353
# 🔹 Debug: Checking Azure Search Index Status
# 353
# Processed 1169_USA_29-CFR-1926_OSHA_Eff-04-2017.pdf: ✅ Document '1169_USA_29-CFR-1926_OSHA_Eff-04-2017.pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.97 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:29:28.549567
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.97 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A29%3A28Z&sp=r&sv=2025-05-05&sr=b&sig=H7gt8SW31g1YUPaGisLmOlfONySuYVPQuu2f8CE/WaQ%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.97 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A29%3A28Z&sp=r&sv=2025-05-05&sr=b&sig=H7gt8SW31g1YUPaGisLmOlfONySuYVPQuu2f8CE/WaQ%3D
# 🔹 Debug: Checking Azure Search Index Status
# 355
# 🔹 Debug: Checking Azure Search Index Status
# 355
# 🔹 Debug: Checking Azure Search Index Status
# 357
# 🔹 Debug: Checking Azure Search Index Status
# 357
# 🔹 Debug: Checking Azure Search Index Status
# 357
# 🔹 Debug: Checking Azure Search Index Status
# 357
# 🔹 Debug: Checking Azure Search Index Status
# 361
# 🔹 Debug: Checking Azure Search Index Status
# 362
# 🔹 Debug: Checking Azure Search Index Status
# 362
# 🔹 Debug: Checking Azure Search Index Status
# 362
# Processed 29 CFR 1926.97 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.97 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.32 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:29:38.077780
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.32 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A29%3A38Z&sp=r&sv=2025-05-05&sr=b&sig=/7LpVvaRdRrVezq6%2BVRpSdXFG5V7vyod%2BTDLNdgtWSM%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.32 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A29%3A38Z&sp=r&sv=2025-05-05&sr=b&sig=/7LpVvaRdRrVezq6%2BVRpSdXFG5V7vyod%2BTDLNdgtWSM%3D
# 🔹 Debug: Checking Azure Search Index Status
# 365
# 🔹 Debug: Checking Azure Search Index Status
# 366
# Processed 29 CFR 1926.32 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.32 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.150 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:29:44.489789
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.150 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A29%3A44Z&sp=r&sv=2025-05-05&sr=b&sig=Tku9tWrAwZ10Rhuycv1TPp6kj6TIFe3yUH800B%2BTvqU%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.150 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A29%3A44Z&sp=r&sv=2025-05-05&sr=b&sig=Tku9tWrAwZ10Rhuycv1TPp6kj6TIFe3yUH800B%2BTvqU%3D
# 🔹 Debug: Checking Azure Search Index Status
# 367
# 🔹 Debug: Checking Azure Search Index Status
# 367
# 🔹 Debug: Checking Azure Search Index Status
# 368
# 🔹 Debug: Checking Azure Search Index Status
# 370
# Processed 29 CFR 1926.150 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.150 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.154 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:29:51.533354
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.154 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A29%3A51Z&sp=r&sv=2025-05-05&sr=b&sig=1nO1GNhuoDxWvjeh79IpHquJJWxdelakZyW2tFjd5Co%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.154 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A29%3A51Z&sp=r&sv=2025-05-05&sr=b&sig=1nO1GNhuoDxWvjeh79IpHquJJWxdelakZyW2tFjd5Co%3D
# 🔹 Debug: Checking Azure Search Index Status
# 372
# 🔹 Debug: Checking Azure Search Index Status
# 372
# Processed 29 CFR 1926.154 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.154 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.29 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:29:56.699577
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.29 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A29%3A56Z&sp=r&sv=2025-05-05&sr=b&sig=av8bOIzN2zMQpIJoWwfsUPhVoJ4/23XNNaHwv%2BVIToo%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.29 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A29%3A56Z&sp=r&sv=2025-05-05&sr=b&sig=av8bOIzN2zMQpIJoWwfsUPhVoJ4/23XNNaHwv%2BVIToo%3D
# 🔹 Debug: Checking Azure Search Index Status
# 373
# Processed 29 CFR 1926.29 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.29 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.252 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:30:01.763218
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.252 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A30%3A01Z&sp=r&sv=2025-05-05&sr=b&sig=f9iA%2B5JUYCy7R2FrBWuD1NgnE0FOMWc%2Bc7Mw/R5IX%2BA%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.252 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A30%3A01Z&sp=r&sv=2025-05-05&sr=b&sig=f9iA%2B5JUYCy7R2FrBWuD1NgnE0FOMWc%2Bc7Mw/R5IX%2BA%3D
# 🔹 Debug: Checking Azure Search Index Status
# 374
# Processed 29 CFR 1926.252 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.252 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.58 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:30:05.615274
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.58 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A30%3A05Z&sp=r&sv=2025-05-05&sr=b&sig=RGJd%2BkGQKICPty/rwjoDUG//SaaKz5x151fFYO5KE8s%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.58 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A30%3A05Z&sp=r&sv=2025-05-05&sr=b&sig=RGJd%2BkGQKICPty/rwjoDUG//SaaKz5x151fFYO5KE8s%3D
# 🔹 Debug: Checking Azure Search Index Status
# 375
# Processed 29 CFR 1926.58 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.58 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.153 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:30:09.492329
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.153 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A30%3A09Z&sp=r&sv=2025-05-05&sr=b&sig=8EE7DpQLkoWZrHSNb6l1KSCrWNW7Ucz7GjaC9jATsvw%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.153 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A30%3A09Z&sp=r&sv=2025-05-05&sr=b&sig=8EE7DpQLkoWZrHSNb6l1KSCrWNW7Ucz7GjaC9jATsvw%3D
# 🔹 Debug: Checking Azure Search Index Status
# 376
# 🔹 Debug: Checking Azure Search Index Status
# 376
# 🔹 Debug: Checking Azure Search Index Status
# 376
# 🔹 Debug: Checking Azure Search Index Status
# 378
# 🔹 Debug: Checking Azure Search Index Status
# 380
# 🔹 Debug: Checking Azure Search Index Status
# 380
# Processed 29 CFR 1926.153 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.153 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.251 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:30:18.351666
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.251 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A30%3A18Z&sp=r&sv=2025-05-05&sr=b&sig=1bZbUihSjuGRNMSTBwAG3CJfNSa7HNO4FwF%2BIX9Ak9E%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.251 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A30%3A18Z&sp=r&sv=2025-05-05&sr=b&sig=1bZbUihSjuGRNMSTBwAG3CJfNSa7HNO4FwF%2BIX9Ak9E%3D
# 🔹 Debug: Checking Azure Search Index Status
# 382
# 🔹 Debug: Checking Azure Search Index Status
# 382
# 🔹 Debug: Checking Azure Search Index Status
# 382
# 🔹 Debug: Checking Azure Search Index Status
# 385
# 🔹 Debug: Checking Azure Search Index Status
# 385
# 🔹 Debug: Checking Azure Search Index Status
# 387
# 🔹 Debug: Checking Azure Search Index Status
# 388
# 🔹 Debug: Checking Azure Search Index Status
# 388
# Processed 29 CFR 1926.251 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.251 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.35 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:30:32.202382
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.35 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A30%3A32Z&sp=r&sv=2025-05-05&sr=b&sig=89ZbfnQyckNubcxKFRA3HLWQAaKB53QPWoqd73C70X0%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.35 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A30%3A32Z&sp=r&sv=2025-05-05&sr=b&sig=89ZbfnQyckNubcxKFRA3HLWQAaKB53QPWoqd73C70X0%3D
# 🔹 Debug: Checking Azure Search Index Status
# 390
# 🔹 Debug: Checking Azure Search Index Status
# 392
# Processed 29 CFR 1926.35 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.35 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.53 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:30:39.952463
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.53 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A30%3A39Z&sp=r&sv=2025-05-05&sr=b&sig=TtmTA72B3hDPtWkRBl%2B7Dvd0hEwP4R35a1p3pmRIBAM%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.53 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A30%3A39Z&sp=r&sv=2025-05-05&sr=b&sig=TtmTA72B3hDPtWkRBl%2B7Dvd0hEwP4R35a1p3pmRIBAM%3D
# 🔹 Debug: Checking Azure Search Index Status
# 392
# Processed 29 CFR 1926.53 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.53 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.200 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:30:47.401279
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.200 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A30%3A47Z&sp=r&sv=2025-05-05&sr=b&sig=srWsAqgLzE8RWTSdsfscCesZP5KH0AEPoJb5Bohqmyw%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.200 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A30%3A47Z&sp=r&sv=2025-05-05&sr=b&sig=srWsAqgLzE8RWTSdsfscCesZP5KH0AEPoJb5Bohqmyw%3D
# 🔹 Debug: Checking Azure Search Index Status
# 393
# 🔹 Debug: Checking Azure Search Index Status
# 393
# 🔹 Debug: Checking Azure Search Index Status
# 395
# Processed 29 CFR 1926.200 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.200 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.106 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:30:53.161631
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.106 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A30%3A53Z&sp=r&sv=2025-05-05&sr=b&sig=Jw4OSr9a025loYgW7QOylnMi2wNjQnzWZ6TJmzu32rQ%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.106 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A30%3A53Z&sp=r&sv=2025-05-05&sr=b&sig=Jw4OSr9a025loYgW7QOylnMi2wNjQnzWZ6TJmzu32rQ%3D
# 🔹 Debug: Checking Azure Search Index Status
# 396
# Processed 29 CFR 1926.106 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.106 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.102 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:30:59.412772
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.102 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A30%3A59Z&sp=r&sv=2025-05-05&sr=b&sig=1En6/n/P47seOtw/V24seOqKjYSBptalQ9cAWNJzepI%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.102 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A30%3A59Z&sp=r&sv=2025-05-05&sr=b&sig=1En6/n/P47seOtw/V24seOqKjYSBptalQ9cAWNJzepI%3D
# 🔹 Debug: Checking Azure Search Index Status
# 397
# 🔹 Debug: Checking Azure Search Index Status
# 397
# 🔹 Debug: Checking Azure Search Index Status
# 399
# Processed 29 CFR 1926.102 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.102 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.57 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:31:07.448641
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.57 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A31%3A07Z&sp=r&sv=2025-05-05&sr=b&sig=lr98C2QjxDerreHTIxzUyFok6rXt1ZsOpzQdBVcPco0%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.57 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A31%3A07Z&sp=r&sv=2025-05-05&sr=b&sig=lr98C2QjxDerreHTIxzUyFok6rXt1ZsOpzQdBVcPco0%3D
# 🔹 Debug: Checking Azure Search Index Status
# 400
# 🔹 Debug: Checking Azure Search Index Status
# 401
# 🔹 Debug: Checking Azure Search Index Status
# 401
# 🔹 Debug: Checking Azure Search Index Status
# 401
# 🔹 Debug: Checking Azure Search Index Status
# 404
# 🔹 Debug: Checking Azure Search Index Status
# 404
# 🔹 Debug: Checking Azure Search Index Status
# 404
# 🔹 Debug: Checking Azure Search Index Status
# 407
# 🔹 Debug: Checking Azure Search Index Status
# 407
# 🔹 Debug: Checking Azure Search Index Status
# 409
# 🔹 Debug: Checking Azure Search Index Status
# 409
# 🔹 Debug: Checking Azure Search Index Status
# 409
# 🔹 Debug: Checking Azure Search Index Status
# 412
# 🔹 Debug: Checking Azure Search Index Status
# 412
# 🔹 Debug: Checking Azure Search Index Status
# 412
# 🔹 Debug: Checking Azure Search Index Status
# 412
# 🔹 Debug: Checking Azure Search Index Status
# 415
# 🔹 Debug: Checking Azure Search Index Status
# 417
# 🔹 Debug: Checking Azure Search Index Status
# 417
# 🔹 Debug: Checking Azure Search Index Status
# 417
# 🔹 Debug: Checking Azure Search Index Status
# 420
# 🔹 Debug: Checking Azure Search Index Status
# 420
# 🔹 Debug: Checking Azure Search Index Status
# 422
# 🔹 Debug: Checking Azure Search Index Status
# 422
# 🔹 Debug: Checking Azure Search Index Status
# 422
# 🔹 Debug: Checking Azure Search Index Status
# 425
# 🔹 Debug: Checking Azure Search Index Status
# 426
# 🔹 Debug: Checking Azure Search Index Status
# 426
# 🔹 Debug: Checking Azure Search Index Status
# 426
# 🔹 Debug: Checking Azure Search Index Status
# 429
# 🔹 Debug: Checking Azure Search Index Status
# 429
# 🔹 Debug: Checking Azure Search Index Status
# 429
# 🔹 Debug: Checking Azure Search Index Status
# 432
# 🔹 Debug: Checking Azure Search Index Status
# 432
# 🔹 Debug: Checking Azure Search Index Status
# 434
# 🔹 Debug: Checking Azure Search Index Status
# 434
# 🔹 Debug: Checking Azure Search Index Status
# 436
# 🔹 Debug: Checking Azure Search Index Status
# 436
# 🔹 Debug: Checking Azure Search Index Status
# 438
# 🔹 Debug: Checking Azure Search Index Status
# 438
# 🔹 Debug: Checking Azure Search Index Status
# 438
# Processed 29 CFR 1926.57 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.57 (up to date as of 3-10-2025).pdf' processed and stored successfully!
# ✅ File '29 CFR 1926.60 (up to date as of 3-10-2025).pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-11-05 17:31:45.898718
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.60 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A31%3A45Z&sp=r&sv=2025-05-05&sr=b&sig=dz2rC41XNPawqtbXtaUUC1Dgqt6Kpu5PVnwPhMCvPZg%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/osha-safety-insight/29 CFR 1926.60 (up to date as of 3-10-2025).pdf?se=2026-11-05T17%3A31%3A45Z&sp=r&sv=2025-05-05&sr=b&sig=dz2rC41XNPawqtbXtaUUC1Dgqt6Kpu5PVnwPhMCvPZg%3D
# 🔹 Debug: Checking Azure Search Index Status
# 441
# 🔹 Debug: Checking Azure Search Index Status
# 441
# 🔹 Debug: Checking Azure Search Index Status
# 443
# 🔹 Debug: Checking Azure Search Index Status
# 444
# 🔹 Debug: Checking Azure Search Index Status
# 445
# 🔹 Debug: Checking Azure Search Index Status
# 445
# 🔹 Debug: Checking Azure Search Index Status
# 445
# 🔹 Debug: Checking Azure Search Index Status
# 448
# 🔹 Debug: Checking Azure Search Index Status
# 450
# 🔹 Debug: Checking Azure Search Index Status
# 450
# 🔹 Debug: Checking Azure Search Index Status
# 450
# 🔹 Debug: Checking Azure Search Index Status
# 450
# 🔹 Debug: Checking Azure Search Index Status
# 453
# 🔹 Debug: Checking Azure Search Index Status
# 453
# 🔹 Debug: Checking Azure Search Index Status
# 453
# 🔹 Debug: Checking Azure Search Index Status
# 456
# 🔹 Debug: Checking Azure Search Index Status
# 456
# 🔹 Debug: Checking Azure Search Index Status
# 458
# 🔹 Debug: Checking Azure Search Index Status
# 458
# 🔹 Debug: Checking Azure Search Index Status
# 458
# 🔹 Debug: Checking Azure Search Index Status
# 462
# Processed 29 CFR 1926.60 (up to date as of 3-10-2025).pdf: ✅ Document '29 CFR 1926.60 (up to date as of 3-10-2025).pdf' processed and stored successfully!
